# %% [markdown]
# ## Navigate and produce .csv tables

# %%
cd ~/local/sarif-cli/data/treeio
# Out:
# /Users/hohn/local/sarif-cli/data/treeio

# %%
# %ls
# Out:
# 2021-12-09/          multi-sarif-01.json  test_set_1.sarif
# 2022-02-25/          multi-sarif-01.yaml  test_set_1.yaml
# base-tables/         test-01/             treeio/

# %%
# !sarif-extract-multi multi-sarif-01.json base-tables

# %%
cd base-tables
# Out:
# /Users/hohn/local/sarif-cli/data/treeio/base-tables

# %%
# %ls
# Out:
# artifacts.csv         kind_problem.csv      rules.csv
# codeflows.csv         project.csv
# kind_pathproblem.csv  relatedLocations.csv

# %% [markdown]
# ## Display adjustments

# %%
from IPython.display import display, HTML

# use full display width
display(HTML("<style>.container { width:95% !important; }</style>"))

# enlarge table font size
display(HTML("<style> .rendered_html table  { font-size: 12pt !important; }</style>"))

display(HTML("<style> .rendered_html th, .rendered_html td { text-align: left !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>
# <style> .rendered_html table  { font-size: 12pt !important; }</style>
# <style> .rendered_html th, .rendered_html td { text-align: left !important; }</style>

# %% [markdown]
# ## Load tables

# %%
import pandas as pd
from collections import UserDict
d1 = UserDict()

# %%
def windowed_view(df):
    return df.style.set_sticky(axis=0).set_sticky(axis=1)

# %%
from pathlib import Path
for p in Path(".").glob("*.csv"):
    d1[p.name] = pd.read_csv(p)

# %% [markdown]
# ## display all column names

# %%
d1.colnames = pd.DataFrame([_df.columns for _df in d1.values()], index=d1.keys()).sort_index().T
windowed_view(d1.colnames.fillna(""))
# Out:
# <style type="text/css">
# #T_a6b5e thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_a6b5e tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# #T_a6b5e thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: white;
#   top: 0px;
#   z-index: 2;
# }
# </style>
# <table id="T_a6b5e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6b5e_level0_col0" class="col_heading level0 col0" >artifacts.csv</th>
#       <th id="T_a6b5e_level0_col1" class="col_heading level0 col1" >codeflows.csv</th>
#       <th id="T_a6b5e_level0_col2" class="col_heading level0 col2" >kind_pathproblem.csv</th>
#       <th id="T_a6b5e_level0_col3" class="col_heading level0 col3" >kind_problem.csv</th>
#       <th id="T_a6b5e_level0_col4" class="col_heading level0 col4" >project.csv</th>
#       <th id="T_a6b5e_level0_col5" class="col_heading level0 col5" >relatedLocations.csv</th>
#       <th id="T_a6b5e_level0_col6" class="col_heading level0 col6" >rules.csv</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6b5e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6b5e_row0_col0" class="data row0 col0" >artifacts_id</td>
#       <td id="T_a6b5e_row0_col1" class="data row0 col1" >codeflow_id</td>
#       <td id="T_a6b5e_row0_col2" class="data row0 col2" >results_array_id</td>
#       <td id="T_a6b5e_row0_col3" class="data row0 col3" >results_array_id</td>
#       <td id="T_a6b5e_row0_col4" class="data row0 col4" >creation_date</td>
#       <td id="T_a6b5e_row0_col5" class="data row0 col5" >struct_id</td>
#       <td id="T_a6b5e_row0_col6" class="data row0 col6" >rules_array_id</td>
#     </tr>
#     <tr>
#       <th id="T_a6b5e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6b5e_row1_col0" class="data row1 col0" >index</td>
#       <td id="T_a6b5e_row1_col1" class="data row1 col1" >codeflow_index</td>
#       <td id="T_a6b5e_row1_col2" class="data row1 col2" >results_array_index</td>
#       <td id="T_a6b5e_row1_col3" class="data row1 col3" >results_array_index</td>
#       <td id="T_a6b5e_row1_col4" class="data row1 col4" >primary_language</td>
#       <td id="T_a6b5e_row1_col5" class="data row1 col5" >uri</td>
#       <td id="T_a6b5e_row1_col6" class="data row1 col6" >rules_array_index</td>
#     </tr>
#     <tr>
#       <th id="T_a6b5e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a6b5e_row2_col0" class="data row2 col0" >uri</td>
#       <td id="T_a6b5e_row2_col1" class="data row2 col1" >threadflow_index</td>
#       <td id="T_a6b5e_row2_col2" class="data row2 col2" >codeFlows_id</td>
#       <td id="T_a6b5e_row2_col3" class="data row2 col3" >ruleId</td>
#       <td id="T_a6b5e_row2_col4" class="data row2 col4" >project_name</td>
#       <td id="T_a6b5e_row2_col5" class="data row2 col5" >startLine</td>
#       <td id="T_a6b5e_row2_col6" class="data row2 col6" >id</td>
#     </tr>
#     <tr>
#       <th id="T_a6b5e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a6b5e_row3_col0" class="data row3 col0" >uriBaseId</td>
#       <td id="T_a6b5e_row3_col1" class="data row3 col1" >location_index</td>
#       <td id="T_a6b5e_row3_col2" class="data row3 col2" >ruleId</td>
#       <td id="T_a6b5e_row3_col3" class="data row3 col3" >ruleIndex</td>
#       <td id="T_a6b5e_row3_col4" class="data row3 col4" >query_commit_id</td>
#       <td id="T_a6b5e_row3_col5" class="data row3 col5" >startColumn</td>
#       <td id="T_a6b5e_row3_col6" class="data row3 col6" >name</td>
#     </tr>
#     <tr>
#       <th id="T_a6b5e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a6b5e_row4_col0" class="data row4 col0" ></td>
#       <td id="T_a6b5e_row4_col1" class="data row4 col1" >endColumn</td>
#       <td id="T_a6b5e_row4_col2" class="data row4 col2" >ruleIndex</td>
#       <td id="T_a6b5e_row4_col3" class="data row4 col3" >location_array_index</td>
#       <td id="T_a6b5e_row4_col4" class="data row4 col4" >sarif_file_name</td>
#       <td id="T_a6b5e_row4_col5" class="data row4 col5" >endLine</td>
#       <td id="T_a6b5e_row4_col6" class="data row4 col6" >enabled</td>
#     </tr>
#     <tr>
#       <th id="T_a6b5e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a6b5e_row5_col0" class="data row5 col0" ></td>
#       <td id="T_a6b5e_row5_col1" class="data row5 col1" >endLine</td>
#       <td id="T_a6b5e_row5_col2" class="data row5 col2" >location_array_index</td>
#       <td id="T_a6b5e_row5_col3" class="data row5 col3" >location_id</td>
#       <td id="T_a6b5e_row5_col4" class="data row5 col4" >scan_id</td>
#       <td id="T_a6b5e_row5_col5" class="data row5 col5" >endColumn</td>
#       <td id="T_a6b5e_row5_col6" class="data row5 col6" >level</td>
#     </tr>
#     <tr>
#       <th id="T_a6b5e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a6b5e_row6_col0" class="data row6 col0" ></td>
#       <td id="T_a6b5e_row6_col1" class="data row6 col1" >startColumn</td>
#       <td id="T_a6b5e_row6_col2" class="data row6 col2" >location_id</td>
#       <td id="T_a6b5e_row6_col3" class="data row6 col3" >location_endColumn</td>
#       <td id="T_a6b5e_row6_col4" class="data row6 col4" >scan_start_date</td>
#       <td id="T_a6b5e_row6_col5" class="data row6 col5" >message</td>
#       <td id="T_a6b5e_row6_col6" class="data row6 col6" >fullDescription</td>
#     </tr>
#     <tr>
#       <th id="T_a6b5e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a6b5e_row7_col0" class="data row7 col0" ></td>
#       <td id="T_a6b5e_row7_col1" class="data row7 col1" >startLine</td>
#       <td id="T_a6b5e_row7_col2" class="data row7 col2" >location_endColumn</td>
#       <td id="T_a6b5e_row7_col3" class="data row7 col3" >location_endLine</td>
#       <td id="T_a6b5e_row7_col4" class="data row7 col4" >scan_stop_date</td>
#       <td id="T_a6b5e_row7_col5" class="data row7 col5" ></td>
#       <td id="T_a6b5e_row7_col6" class="data row7 col6" >shortDescription</td>
#     </tr>
#     <tr>
#       <th id="T_a6b5e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a6b5e_row8_col0" class="data row8 col0" ></td>
#       <td id="T_a6b5e_row8_col1" class="data row8 col1" >artifact_index</td>
#       <td id="T_a6b5e_row8_col2" class="data row8 col2" >location_endLine</td>
#       <td id="T_a6b5e_row8_col3" class="data row8 col3" >location_startColumn</td>
#       <td id="T_a6b5e_row8_col4" class="data row8 col4" >tool_name</td>
#       <td id="T_a6b5e_row8_col5" class="data row8 col5" ></td>
#       <td id="T_a6b5e_row8_col6" class="data row8 col6" >kind</td>
#     </tr>
#     <tr>
#       <th id="T_a6b5e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a6b5e_row9_col0" class="data row9 col0" ></td>
#       <td id="T_a6b5e_row9_col1" class="data row9 col1" >uri</td>
#       <td id="T_a6b5e_row9_col2" class="data row9 col2" >location_startColumn</td>
#       <td id="T_a6b5e_row9_col3" class="data row9 col3" >location_startLine</td>
#       <td id="T_a6b5e_row9_col4" class="data row9 col4" >tool_version</td>
#       <td id="T_a6b5e_row9_col5" class="data row9 col5" ></td>
#       <td id="T_a6b5e_row9_col6" class="data row9 col6" >precision</td>
#     </tr>
#     <tr>
#       <th id="T_a6b5e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a6b5e_row10_col0" class="data row10 col0" ></td>
#       <td id="T_a6b5e_row10_col1" class="data row10 col1" >uriBaseId</td>
#       <td id="T_a6b5e_row10_col2" class="data row10 col2" >location_startLine</td>
#       <td id="T_a6b5e_row10_col3" class="data row10 col3" >location_index</td>
#       <td id="T_a6b5e_row10_col4" class="data row10 col4" >$schema</td>
#       <td id="T_a6b5e_row10_col5" class="data row10 col5" ></td>
#       <td id="T_a6b5e_row10_col6" class="data row10 col6" >security-severity</td>
#     </tr>
#     <tr>
#       <th id="T_a6b5e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a6b5e_row11_col0" class="data row11 col0" ></td>
#       <td id="T_a6b5e_row11_col1" class="data row11 co

# %% [markdown]
# ## ... and get details of some tables

# %%
d1['project.csv'].T
# Out:
#                                                                         0  \
# creation_date                                                  2021-12-09
# primary_language                                               javascript
# project_name                                                treeio/treeio
# query_commit_id                                                fa9571646c
# sarif_file_name                                  2021-12-09/results.sarif
# scan_id                                                            123456
# scan_start_date                                                2021-12-09
# scan_stop_date                                                 2021-12-10
# tool_name                                                          codeql
# tool_version                                                        v1.27
# $schema                 https://raw.githubusercontent.com/oasis-tcs/sa...
# sarif_version                                                       2.1.0
# run_index                                                               0
# artifacts                                                      4793680000
# columnKind                                                 utf16CodeUnits
# results                                                        4793680256
# semmle.formatSpecifier                                              2.1.0
# semmle.sourceLanguage                                          javascript
# driver_name                                                      LGTM.com
# organization                                                       Semmle
# rules                                                          4796114688
# driver_version                                            1.29.0-SNAPSHOT
# repositoryUri                        https://github.com/treeio/treeio.git
# revisionId                       bae3115f4015aad2cbc5ab45572232ceec990495
#
#                                                                         1  \
# creation_date                                                  2021-12-09
# primary_language                                               javascript
# project_name                                                treeio/treeio
# query_commit_id                                                fa9571646c
# sarif_file_name                                  2021-12-09/results.sarif
# scan_id                                                            123456
# scan_start_date                                                2021-12-09
# scan_stop_date                                                 2021-12-10
# tool_name                                                          codeql
# tool_version                                                        v1.27
# $schema                 https://raw.githubusercontent.com/oasis-tcs/sa...
# sarif_version                                                       2.1.0
# run_index                                                               1
# artifacts                                                      4796114368
# columnKind                                              unicodeCodePoints
# results                                                        4796141696
# semmle.formatSpecifier                                              2.1.0
# semmle.sourceLanguage                                              python
# driver_name                                                      LGTM.com
# organization                                                       Semmle
# rules                                                          4797609472
# driver_version                                            1.29.0-SNAPSHOT
# repositoryUri                        https://github.com/treeio/treeio.git
# revisionId                       bae3115f4015aad2cbc5ab45572232ceec990495
#
#                                                                     2  \
# creation_date                                              2022-02-25
# primary_language                                           javascript
# project_name                                            treeio/treeio
# query_commit_id                                            fa9571646c
# sarif_file_name                              2022-02-25/results.sarif
# scan_id                                                        123457
# scan_start_date                                            2022-02-25
# scan_stop_date                                             2022-02-26
# tool_name                                                      codeql
# tool_version                                                    v1.29
# $schema                 https://json.schemastore.org/sarif-2.1.0.json
# sarif_version                                                   2.1.0
# run_index                                                           0
# artifacts                                                  4797609984
# columnKind                                          unicodeCodePoints
# results                                                    4797623616
# semmle.formatSpecifier                                          2.1.0
# semmle.sourceLanguage                                          python
# driver_name                                                  LGTM.com
# organization                                                   Semmle
# rules                                                      4799032000
# driver_version                                        1.31.0-SNAPSHOT
# repositoryUri                    https://github.com/treeio/treeio.git
# revisionId                   bae3115f4015aad2cbc5ab45572232ceec990495
#
#                                                                     3
# creation_date                                              2022-02-25
# primary_language                                           javascript
# project_name                                            treeio/treeio
# query_commit_id                                            fa9571646c
# sarif_file_name                              2022-02-25/results.sarif
# scan_id                                                        123457
# scan_start_date                                            2022-02-25
# scan_stop_date                                             2022-02-26
# tool_name                                                      codeql
# tool_version                                                    v1.29
# $schema                 https://json.schemastore.org/sarif-2.1.0.json
# sarif_version                                                   2.1.0
# run_index                                                           1
# artifacts                                                  4799031488
# columnKind                                             utf16CodeUnits
# results                                                    4799032384
# semmle.formatSpecifier                                          2.1.0
# semmle.sourceLanguage                                      javascript
# driver_name                                                  LGTM.com
# organization                                                   Semmle
# rules                                                      4800968384
# driver_version                                        1.31.0-SNAPSHOT
# repositoryUri                    https://github.com/treeio/treeio.git
# revisionId                   bae3115f4015aad2cbc5ab45572232ceec990495

# %%
d1["artifacts.csv"].T
# Out:
#                                     0                      1    \
# artifacts_id                 4793680000             4793680000
# index                                 0                      1
# uri           static/js/fileuploader.js  static/js/hardtree.js
# uriBaseId                     %SRCROOT%              %SRCROOT%
#
#                                                             2    \
# artifacts_id                                         4793680000
# index                                                         2
# uri           static/js/jquery-ui-1.10.3/demos/accordion/hov...
# uriBaseId                                             %SRCROOT%
#
#                                         3    \
# artifacts_id                     4793680000
# index                                     3
# uri           static/js/jquery.ganttView.js
# uriBaseId                         %SRCROOT%
#
#                                                             4    \
# artifacts_id                                         4793680000
# index                                                         4
# uri           static/js/tinymce/jscripts/tiny_mce/plugins/ad...
# uriBaseId                                             %SRCROOT%
#
#                                                             5    \
# artifacts_id                                         4793680000
# index                                                         5
# uri           static/js/tinymce/jscripts/tiny_mce/plugins/ad...
# uriBaseId                                             %SRCROOT%
#
#                                                             6    \
# artifacts_id                                         4793680000
# index                                                         6
# uri           static/js/tinymce/jscripts/tiny_mce/plugins/co...
# uriBaseId                                             %SRCROOT%
#
#                                                             7    \
# artifacts_id                                         4793680000
# index                                                         7
# uri           static/js/tinymce/jscripts/tiny_mce/plugins/em...
# uriBaseId                                             %SRCROOT%
#
#                                                             8    \
# artifacts_id                                         4793680000
# index                                                         8
# uri           static/js/tinymce/jscripts/tiny_mce/plugins/fu...
# uriBaseId                                             %SRCROOT%
#
#                                                             9    ...  \
# artifacts_id                                         4793680000  ...
# index                                                         9  ...
# uri           static/js/tinymce/jscripts/tiny_mce/plugins/fu...  ...
# uriBaseId                                             %SRCROOT%  ...
#
#                                                  353  \
# artifacts_id                              4799031488
# index                                             66
# uri           static/js/jquery.ba-serializeobject.js
# uriBaseId                                  %SRCROOT%
#
#                                                             354  \
# artifacts_id                                         4799031488
# index                                                        67
# uri           static/js/jquery-ui-1.10.3/ui/jquery.ui.button.js
# uriBaseId                                             %SRCROOT%
#
#                                                           355  \
# artifacts_id                                       4799031488
# index                                                      68
# uri           static/js/jquery-ui-1.10.3/ui/jquery.ui.tabs.js
# uriBaseId                                           %SRCROOT%
#
#                                                             356  \
# artifacts_id                                         4799031488
# index                                                        69
# uri           static/js/jquery-ui-1.10.3/ui/jquery.ui.sortab...
# uriBaseId                                             %SRCROOT%
#
#                                                             357  \
# artifacts_id                                         4799031488
# index                                                        70
# uri           static/js/jquery-ui-1.10.3/ui/jquery.ui.droppa...
# uriBaseId                                             %SRCROOT%
#
#                                                      358  \
# artifacts_id                                  4799031488
# index                                                 71
# uri           static/js/jquery-ui-1.10.3/ui/jquery-ui.js
# uriBaseId                                      %SRCROOT%
#
#                                         359  \
# artifacts_id                     4799031488
# index                                    72
# uri           static/js/jquery-ui-custom.js
# uriBaseId                         %SRCROOT%
#
#                                                             360  \
# artifacts_id                                         4799031488
# index                                                        73
# uri           static/js/jquery-ui-1.10.3/ui/jquery.ui.positi...
# uriBaseId                                             %SRCROOT%
#
#                                                             361  \
# artifacts_id                                         4799031488
# index                                                        74
# uri           static/js/jquery-ui-1.10.3/demos/droppable/pho...
# uriBaseId                                             %SRCROOT%
#
#                                                             362
# artifacts_id                                         4799031488
# index                                                        75
# uri           static/js/jquery-ui-1.10.3/demos/tabs/manipula...
# uriBaseId                                             %SRCROOT%
#
# [4 rows x 363 columns]

# %%
(d1["codeflows.csv"]).T
# Out:
#                                                          0    \
# codeflow_id                                       4795838400
# codeflow_index                                             0
# threadflow_index                                           0
# location_index                                             0
# endColumn                                                 35
# endLine                                                 9598
# startColumn                                               28
# startLine                                               9598
# artifact_index                                            72
# uri               static/js/jquery-ui-1.10.3/ui/jquery-ui.js
# uriBaseId                                          %SRCROOT%
# message                                              options
#
#                                                          1    \
# codeflow_id                                       4795838400
# codeflow_index                                             0
# threadflow_index                                           0
# location_index                                             1
# endColumn                                                 48
# endLine                                                 9629
# startColumn                                               41
# startLine                                               9629
# artifact_index                                            72
# uri               static/js/jquery-ui-1.10.3/ui/jquery-ui.js
# uriBaseId                                          %SRCROOT%
# message                                              options
#
#                                                                 2    \
# codeflow_id                                              4795838400
# codeflow_index                                                    0
# threadflow_index                                                  0
# location_index                                                    2
# endColumn                                                        46
# endLine                                                         139
# startColumn                                                      38
# startLine                                                       139
# artifact_index                                                   61
# uri               static/js/jquery-ui-1.10.3/ui/jquery.ui.datepi...
# uriBaseId                                                 %SRCROOT%
# message                                                    settings
#
#                                                                 3    \
# codeflow_id                                              4795838400
# codeflow_index                                                    0
# threadflow_index                                                  0
# location_index                                                    3
# endColumn                                                        40
# endLine                                                         148
# startColumn                                                      32
# startLine                                                       148
# artifact_index                                                   61
# uri               static/js/jquery-ui-1.10.3/ui/jquery.ui.datepi...
# uriBaseId                                                 %SRCROOT%
# message                                                    settings
#
#                                                                 4    \
# codeflow_id                                              4795838400
# codeflow_index                                                    0
# threadflow_index                                                  0
# location_index                                                    4
# endColumn                                                        46
# endLine                                                         148
# startColumn                                                      32
# startLine                                                       148
# artifact_index                                                   61
# uri               static/js/jquery-ui-1.10.3/ui/jquery.ui.datepi...
# uriBaseId                                                 %SRCROOT%
# message                                              settings || {}
#
#                                                                 5    \
# codeflow_id                                              4795838400
# codeflow_index                                                    0
# threadflow_index                                                  0
# location_index                                                    5
# endColumn                                                        47
# endLine                                                         148
# startColumn                                                      19
# startLine                                                       148
# artifact_index                                                   61
# uri               static/js/jquery-ui-1.10.3/ui/jquery.ui.datepi...
# uriBaseId                                                 %SRCROOT%
# message                                         $.exten ...  || {})
#
#                                                                 6    \
# codeflow_id                                              4795838400
# codeflow_index                                                    0
# threadflow_index                                                  0
# location_index                                                    6
# endColumn                                                        42
# endLine                                                        1021
# startColumn                                                      15
# startLine                                                      1021
# artifact_index                                                   61
# uri               static/js/jquery-ui-1.10.3/ui/jquery.ui.datepi...
# uriBaseId                                                 %SRCROOT%
# message                                         this._g ... Field")
#
#                                                                 7    \
# codeflow_id                                              4795838400
# codeflow_index                                                    0
# threadflow_index                                                  0
# location_index                                                    7
# endColumn                                                        42
# endLine                                                        1021
# startColumn                                                       4
# startLine                                                      1021
# artifact_index                                                   61
# uri               static/js/jquery-ui-1.10.3/ui/jquery.ui.datepi...
# uriBaseId                                                 %SRCROOT%
# message                                                    altField
#
#                                                                 8    \
# codeflow_id                                              4795838400
# codeflow_index                                                    0
# threadflow_index                                                  0
# location_index                                                    8
# endColumn                                                        14
# endLine                                                        1027
# startColumn                                                       6
# startLine                                                      1027
# artifact_index                                                   61
# uri               static/js/jquery-ui-1.10.3/ui/jquery.ui.datepi...
# uriBaseId                                                 %SRCROOT%
# message                                                    altField
#
#                                                          9    ...  \
# codeflow_id                                       4795838400  ...
# codeflow_index                                             1  ...
# threadflow_index                                           0  ...
# location_index                                             0  ...
# endColumn                                                 35  ...
# endLine                                                 9598  ...
# startColumn                                               28  ...
# startLine                                               9598  ...
# artifact_index                                            72  ...
# uri               static/js/jquery-ui-1.10.3/ui/jquery-ui.js  ...
# uriBaseId                                          %SRCROOT%  ...
# message                                              options  ...
#
#                                             336  \
# codeflow_id                          4800898624
# codeflow_index                                5
# threadflow_index                              0
# location_index                                0
# endColumn                                    11
# endLine                                     541
# startColumn                                  10
# startLine                                   541
# artifact_index                               72
# uri               static/js/jquery-ui-custom.js
# uriBaseId                             %SRCROOT%
# message                                       a
#
#                                             337  \
# codeflow_id                          4800898624
# codeflow_index                                5
# threadflow_index                              0
# location_index                                1
# endColumn                                   155
# endLine                                     542
# startColumn                                 154
# startLine                                   542
# artifact_index                               72
# uri               static/js/jquery-ui-custom.js
# uriBaseId                             %SRCROOT%
# message                                       a
#
#                                                                 338  \
# codeflow_id                                              4800898624
# codeflow_index                                                    5
# threadflow_index                                                  0
# location_index                                                    2
# endColumn                                                        46
# endLine                                                         139
# startColumn                                                      38
# startLine                                                       139
# artifact_index                                                   60
# uri               static/js/jquery-ui-1.10.3/ui/jquery.ui.datepi...
# uriBaseId                                                 %SRCROOT%
# message                                                    settings
#
#                                                                 339  \
# codeflow_id                                              4800898624
# codeflow_index                                                    5
# threadflow_index                                                  0
# location_index                                                    3
# endColumn                                                        40
# endLine                                                         148
# startColumn                                                      32
# startLine                                                       148
# artifact_index                                                   60
# uri               static/js/jquery-ui-1.10.3/ui/jquery.ui.datepi...
# uriBaseId                                                 %SRCROOT%
# message                                                    settings
#
#                                                                 340  \
# codeflow_id                                              4800898624
# codeflow_index                                                    5
# threadflow_index                                                  0
# location_index                                                    4
# endColumn                                                        46
# endLine                                                         148
# startColumn                                                      32
# startLine                                                       148
# artifact_index                                                   60
# uri               static/js/jquery-ui-1.10.3/ui/jquery.ui.datepi...
# uriBaseId                                                 %SRCROOT%
# message                                              settings || {}
#
#                                                                 341  \
# codeflow_id                                              4800898624
# codeflow_index                                                    5
# threadflow_index                                                  0
# location_index                                                    5
# endColumn                                                        30
# endLine                                                         148
# startColumn                                                      28
# startLine                                                       148
# artifact_index                                                   60
# uri               static/js/jquery-ui-1.10.3/ui/jquery.ui.datepi...
# uriBaseId                                                 %SRCROOT%
# message                                                          {}
#
#                                                                 342  \
# codeflow_id                                              4800898624
# codeflow_index                                                    5
# threadflow_index                                                  0
# location_index                                                    6
# endColumn                                                        47
# endLine                                                         148
# startColumn                                                      19
# startLine                                                       148
# artifact_index                                                   60
# uri               static/js/jquery-ui-1.10.3/ui/jquery.ui.datepi...
# uriBaseId                                                 %SRCROOT%
# message                                         $.exten ...  || {})
#
#                                                                 343  \
# codeflow_id                                              4800898624
# codeflow_index                                                    5
# threadflow_index                                                  0
# location_index                                                    7
# endColumn                                                        46
# endLine                                                         189
# startColumn                                                      17
# startLine                                                       189
# artifact_index                                                   60
# uri               static/js/jquery-ui-1.10.3/ui/jquery.ui.datepi...
# uriBaseId                                                 %SRCROOT%
# message                                         this._g ... dText")
#
#                                                                 344  \
# codeflow_id                                              4800898624
# codeflow_index                                                    5
# threadflow_index                                                  0
# location_index                                                    8
# endColumn                                                        46
# endLine                                                         189
# startColumn                                                       4
# startLine                                                       189
# artifact_index                                                   60
# uri               static/js/jquery-ui-1.10.3/ui/jquery.ui.datepi...
# uriBaseId                                                 %SRCROOT%
# message                                                  appendText
#
#                                                                 345
# codeflow_id                                              4800898624
# codeflow_index                                                    5
# threadflow_index                                                  0
# location_index                                                    9
# endColumn                                                        75
# endLine                                                         196
# startColumn                                                      65
# startLine                                                       196
# artifact_index                                                   60
# uri               static/js/jquery-ui-1.10.3/ui/jquery.ui.datepi...
# uriBaseId                                                 %SRCROOT%
# message                                                  appendText
#
# [12 rows x 346 columns]

# %%
windowed_view(d1["kind_pathproblem.csv"].T)
# Out:
# <style type="text/css">
# #T_200e0 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_200e0 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# #T_200e0 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: white;
#   top: 0px;
#   z-index: 2;
# }
# </style>
# <table id="T_200e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_200e0_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_200e0_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_200e0_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_200e0_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_200e0_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_200e0_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_200e0_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_200e0_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_200e0_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_200e0_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_200e0_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_200e0_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_200e0_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_200e0_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_200e0_level0_col14" class="col_heading level0 col14" >14</th>
#       <th id="T_200e0_level0_col15" class="col_heading level0 col15" >15</th>
#       <th id="T_200e0_level0_col16" class="col_heading level0 col16" >16</th>
#       <th id="T_200e0_level0_col17" class="col_heading level0 col17" >17</th>
#       <th id="T_200e0_level0_col18" class="col_heading level0 col18" >18</th>
#       <th id="T_200e0_level0_col19" class="col_heading level0 col19" >19</th>
#       <th id="T_200e0_level0_col20" class="col_heading level0 col20" >20</th>
#       <th id="T_200e0_level0_col21" class="col_heading level0 col21" >21</th>
#       <th id="T_200e0_level0_col22" class="col_heading level0 col22" >22</th>
#       <th id="T_200e0_level0_col23" class="col_heading level0 col23" >23</th>
#       <th id="T_200e0_level0_col24" class="col_heading level0 col24" >24</th>
#       <th id="T_200e0_level0_col25" class="col_heading level0 col25" >25</th>
#       <th id="T_200e0_level0_col26" class="col_heading level0 col26" >26</th>
#       <th id="T_200e0_level0_col27" class="col_heading level0 col27" >27</th>
#       <th id="T_200e0_level0_col28" class="col_heading level0 col28" >28</th>
#       <th id="T_200e0_level0_col29" class="col_heading level0 col29" >29</th>
#       <th id="T_200e0_level0_col30" class="col_heading level0 col30" >30</th>
#       <th id="T_200e0_level0_col31" class="col_heading level0 col31" >31</th>
#       <th id="T_200e0_level0_col32" class="col_heading level0 col32" >32</th>
#       <th id="T_200e0_level0_col33" class="col_heading level0 col33" >33</th>
#       <th id="T_200e0_level0_col34" class="col_heading level0 col34" >34</th>
#       <th id="T_200e0_level0_col35" class="col_heading level0 col35" >35</th>
#       <th id="T_200e0_level0_col36" class="col_heading level0 col36" >36</th>
#       <th id="T_200e0_level0_col37" class="col_heading level0 col37" >37</th>
#       <th id="T_200e0_level0_col38" class="col_heading level0 col38" >38</th>
#       <th id="T_200e0_level0_col39" class="col_heading level0 col39" >39</th>
#       <th id="T_200e0_level0_col40" class="col_heading level0 col40" >40</th>
#       <th id="T_200e0_level0_col41" class="col_heading level0 col41" >41</th>
#       <th id="T_200e0_level0_col42" class="col_heading level0 col42" >42</th>
#       <th id="T_200e0_level0_col43" class="col_heading level0 col43" >43</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_200e0_level0_row0" class="row_heading level0 row0" >results_array_id</th>
#       <td id="T_200e0_row0_col0" class="data row0 col0" >4793680256</td>
#       <td id="T_200e0_row0_col1" class="data row0 col1" >4793680256</td>
#       <td id="T_200e0_row0_col2" class="data row0 col2" >4793680256</td>
#       <td id="T_200e0_row0_col3" class="data row0 col3" >4793680256</td>
#       <td id="T_200e0_row0_col4" class="data row0 col4" >4793680256</td>
#       <td id="T_200e0_row0_col5" class="data row0 col5" >4793680256</td>
#       <td id="T_200e0_row0_col6" class="data row0 col6" >4793680256</td>
#       <td id="T_200e0_row0_col7" class="data row0 col7" >4793680256</td>
#       <td id="T_200e0_row0_col8" class="data row0 col8" >4793680256</td>
#       <td id="T_200e0_row0_col9" class="data row0 col9" >4793680256</td>
#       <td id="T_200e0_row0_col10" class="data row0 col10" >4793680256</td>
#       <td id="T_200e0_row0_col11" class="data row0 col11" >4793680256</td>
#       <td id="T_200e0_row0_col12" class="data row0 col12" >4793680256</td>
#       <td id="T_200e0_row0_col13" class="data row0 col13" >4793680256</td>
#       <td id="T_200e0_row0_col14" class="data row0 col14" >4793680256</td>
#       <td id="T_200e0_row0_col15" class="data row0 col15" >4793680256</td>
#       <td id="T_200e0_row0_col16" class="data row0 col16" >4793680256</td>
#       <td id="T_200e0_row0_col17" class="data row0 col17" >4793680256</td>
#       <td id="T_200e0_row0_col18" class="data row0 col18" >4793680256</td>
#       <td id="T_200e0_row0_col19" class="data row0 col19" >4796141696</td>
#       <td id="T_200e0_row0_col20" class="data row0 col20" >4796141696</td>
#       <td id="T_200e0_row0_col21" class="data row0 col21" >4796141696</td>
#       <td id="T_200e0_row0_col22" class="data row0 col22" >4797623616</td>
#       <td id="T_200e0_row0_col23" class="data row0 col23" >4797623616</td>
#       <td id="T_200e0_row0_col24" class="data row0 col24" >4797623616</td>
#       <td id="T_200e0_row0_col25" class="data row0 col25" >4799032384</td>
#       <td id="T_200e0_row0_col26" class="data row0 col26" >4799032384</td>
#       <td id="T_200e0_row0_col27" class="data row0 col27" >4799032384</td>
#       <td id="T_200e0_row0_col28" class="data row0 col28" >4799032384</td>
#       <td id="T_200e0_row0_col29" class="data row0 col29" >4799032384</td>
#       <td id="T_200e0_row0_col30" class="data row0 col30" >4799032384</td>
#       <td id="T_200e0_row0_col31" class="data row0 col31" >4799032384</td>
#       <td id="T_200e0_row0_col32" class="data row0 col32" >4799032384</td>
#       <td id="T_200e0_row0_col33" class="data row0 col33" >4799032384</td>
#       <td id="T_200e0_row0_col34" class="data row0 col34" >4799032384</td>
#       <td id="T_200e0_row0_col35" class="data row0 col35" >4799032384</td>
#       <td id="T_200e0_row0_col36" class="data row0 col36" >4799032384</td>
#       <td id="T_200e0_row0_col37" class="data row0 col37" >4799032384</td>
#       <td id="T_200e0_row0_col38" class="data row0 col38" >4799032384</td>
#       <td id="T_200e0_row0_col39" class="data row0 col39" >4799032384</td>
#       <td id="T_200e0_row0_col40" class="data row0 col40" >4799032384</td>
#       <td id="T_200e0_row0_col41" class="data row0 col41" >4799032384</td>
#       <td id="T_200e0_row0_col42" class="data row0 col42" >4799032384</td>
#       <td id="T_200e0_row0_col43" class="data row0 col43" >4799032384</td>
#     </tr>
#     <tr>
#       <th id="T_200e0_level0_row1" class="row_heading level0 row1" >results_array_index</th>
#       <td id="T_200e0_row1_col0" class="data row1 col0" >564</td>
#       <td id="T_200e0_row1_col1" class="data row1 col1" >564</td>
#       <td id="T_200e0_row1_col2" class="data row1 col2" >564</td>
#       <td id="T_200e0_row1_col3" class="data row1 col3" >565</td>
#       <td id="T_200e0_row1_col4" class="data row1 col4" >566</td>
#       <td id="T_200e0_row1_col5" class="data row1 col5" >567</td>
#       <td id="T_200e0_row1_col6" class="data row1 col6" >568</td>
#       <td id="T_200e0_row1_col7" class="data row1 col7" >569</td>
#       <td id="T_200e0_row1_col8" class="data row1 col8" >570</td>
#       <td id="T_200

# %%
(d1["kind_problem.csv"].T)
# Out:
#                                                                                     0     \
# results_array_id                                                              4793680256
# results_array_index                                                                    0
# ruleId                                 com.lgtm/javascript-queries:js/unused-local-va...
# ruleIndex                                                                              0
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                    17
# location_endLine                                                                    1214
# location_startColumn                                                                  13
# location_startLine                                                                  1214
# location_index                                                                         0
# location_uri                                                   static/js/fileuploader.js
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                    -1
# relatedLocation_endColumn                                                             -1
# relatedLocation_endLine                                                               -1
# relatedLocation_startColumn                                                            1
# relatedLocation_startLine                                                             -1
# relatedLocation_index                                                                 -1
# relatedLocation_uri                                                scli-dyys dummy value
# relatedLocation_uriBaseId                                          scli-dyys dummy value
# relatedLocation_message                                            scli-dyys dummy value
# message_text                                                       Unused variable size.
# primaryLocationLineHash                                               e4aa64838c776437:1
# primaryLocationStartColumnFingerprint                                                  0
# rule_id                                com.lgtm/javascript-queries:js/unused-local-va...
# rule_index                                                                             0
#
#                                                                                     1     \
# results_array_id                                                              4793680256
# results_array_index                                                                    1
# ruleId                                 com.lgtm/javascript-queries:js/unused-local-va...
# ruleIndex                                                                              0
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                    30
# location_endLine                                                                     847
# location_startColumn                                                                  17
# location_startLine                                                                   847
# location_index                                                                         1
# location_uri                                                       static/js/hardtree.js
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                    -1
# relatedLocation_endColumn                                                             -1
# relatedLocation_endLine                                                               -1
# relatedLocation_startColumn                                                            1
# relatedLocation_startLine                                                             -1
# relatedLocation_index                                                                 -1
# relatedLocation_uri                                                scli-dyys dummy value
# relatedLocation_uriBaseId                                          scli-dyys dummy value
# relatedLocation_message                                            scli-dyys dummy value
# message_text                                              Unused variable file_uploader.
# primaryLocationLineHash                                               2d69a7ff25c11755:1
# primaryLocationStartColumnFingerprint                                                  4
# rule_id                                com.lgtm/javascript-queries:js/unused-local-va...
# rule_index                                                                             0
#
#                                                                                     2     \
# results_array_id                                                              4793680256
# results_array_index                                                                    2
# ruleId                                 com.lgtm/javascript-queries:js/unused-local-va...
# ruleIndex                                                                              0
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                    30
# location_endLine                                                                     869
# location_startColumn                                                                  17
# location_startLine                                                                   869
# location_index                                                                         1
# location_uri                                                       static/js/hardtree.js
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                    -1
# relatedLocation_endColumn                                                             -1
# relatedLocation_endLine                                                               -1
# relatedLocation_startColumn                                                            1
# relatedLocation_startLine                                                             -1
# relatedLocation_index                                                                 -1
# relatedLocation_uri                                                scli-dyys dummy value
# relatedLocation_uriBaseId                                          scli-dyys dummy value
# relatedLocation_message                                            scli-dyys dummy value
# message_text                                              Unused variable file_uploader.
# primaryLocationLineHash                                               2d69a7ff25c11755:2
# primaryLocationStartColumnFingerprint                                                  4
# rule_id                                com.lgtm/javascript-queries:js/unused-local-va...
# rule_index                                                                             0
#
#                                                                                     3     \
# results_array_id                                                              4793680256
# results_array_index                                                                    3
# ruleId                                 com.lgtm/javascript-queries:js/unused-local-va...
# ruleIndex                                                                              0
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                    16
# location_endLine                                                                     932
# location_startColumn                                                                  10
# location_startLine                                                                   932
# location_index                                                                         1
# location_uri                                                       static/js/hardtree.js
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                    -1
# relatedLocation_endColumn                                                             -1
# relatedLocation_endLine                                                               -1
# relatedLocation_startColumn                                                            1
# relatedLocation_startLine                                                             -1
# relatedLocation_index                                                                 -1
# relatedLocation_uri                                                scli-dyys dummy value
# relatedLocation_uriBaseId                                          scli-dyys dummy value
# relatedLocation_message                                            scli-dyys dummy value
# message_text                                                     Unused variable target.
# primaryLocationLineHash                                               f53acefb9d43eca1:1
# primaryLocationStartColumnFingerprint                                                  4
# rule_id                                com.lgtm/javascript-queries:js/unused-local-va...
# rule_index                                                                             0
#
#                                                                                     4     \
# results_array_id                                                              4793680256
# results_array_index                                                                    4
# ruleId                                 com.lgtm/javascript-queries:js/unused-local-va...
# ruleIndex                                                                              0
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                     9
# location_endLine                                                                      33
# location_startColumn                                                                   5
# location_startLine                                                                    33
# location_index                                                                         2
# location_uri                           static/js/jquery-ui-1.10.3/demos/accordion/hov...
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                    -1
# relatedLocation_endColumn                                                             -1
# relatedLocation_endLine                                                               -1
# relatedLocation_startColumn                                                            1
# relatedLocation_startLine                                                             -1
# relatedLocation_index                                                                 -1
# relatedLocation_uri                                                scli-dyys dummy value
# relatedLocation_uriBaseId                                          scli-dyys dummy value
# relatedLocation_message                                            scli-dyys dummy value
# message_text                                                       Unused variable args.
# primaryLocationLineHash                                               c700eb701f79d0d0:1
# primaryLocationStartColumnFingerprint                                                  0
# rule_id                                com.lgtm/javascript-queries:js/unused-local-va...
# rule_index                                                                             0
#
#                                                                                     5     \
# results_array_id                                                              4793680256
# results_array_index                                                                    5
# ruleId                                 com.lgtm/javascript-queries:js/unused-local-va...
# ruleIndex                                                                              0
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                    16
# location_endLine                                                                      94
# location_startColumn                                                                   8
# location_startLine                                                                    94
# location_index                                                                         3
# location_uri                                               static/js/jquery.ganttView.js
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                    -1
# relatedLocation_endColumn                                                             -1
# relatedLocation_endLine                                                               -1
# relatedLocation_startColumn                                                            1
# relatedLocation_startLine                                                             -1
# relatedLocation_index                                                                 -1
# relatedLocation_uri                                                scli-dyys dummy value
# relatedLocation_uriBaseId                                          scli-dyys dummy value
# relatedLocation_message                                            scli-dyys dummy value
# message_text                                                   Unused variable divchart.
# primaryLocationLineHash                                               ae729c9a998d74ca:1
# primaryLocationStartColumnFingerprint                                                  4
# rule_id                                com.lgtm/javascript-queries:js/unused-local-va...
# rule_index                                                                             0
#
#                                                                                     6     \
# results_array_id                                                              4793680256
# results_array_index                                                                    6
# ruleId                                 com.lgtm/javascript-queries:js/unused-local-va...
# ruleIndex                                                                              0
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                    19
# location_endLine                                                                     394
# location_startColumn                                                                   9
# location_startLine                                                                   394
# location_index                                                                         3
# location_uri                                               static/js/jquery.ganttView.js
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                    -1
# relatedLocation_endColumn                                                             -1
# relatedLocation_endLine                                                               -1
# relatedLocation_startColumn                                                            1
# relatedLocation_startLine                                                             -1
# relatedLocation_index                                                                 -1
# relatedLocation_uri                                                scli-dyys dummy value
# relatedLocation_uriBaseId                                          scli-dyys dummy value
# relatedLocation_message                                            scli-dyys dummy value
# message_text                                                 Unused variable ArrayUtils.
# primaryLocationLineHash                                               141267900b8cd48b:1
# primaryLocationStartColumnFingerprint                                                  4
# rule_id                                com.lgtm/javascript-queries:js/unused-local-va...
# rule_index                                                                             0
#
#                                                                                     7     \
# results_array_id                                                              4793680256
# results_array_index                                                                    7
# ruleId                                 com.lgtm/javascript-queries:js/unused-local-va...
# ruleIndex                                                                              0
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                    74
# location_endLine                                                                     119
# location_startColumn                                                                  73
# location_startLine                                                                   119
# location_index                                                                         4
# location_uri                           static/js/tinymce/jscripts/tiny_mce/plugins/ad...
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                    -1
# relatedLocation_endColumn                                                             -1
# relatedLocation_endLine                                                               -1
# relatedLocation_startColumn                                                            1
# relatedLocation_startLine                                                             -1
# relatedLocation_index                                                                 -1
# relatedLocation_uri                                                scli-dyys dummy value
# relatedLocation_uriBaseId                                          scli-dyys dummy value
# relatedLocation_message                                            scli-dyys dummy value
# message_text                                                          Unused variable v.
# primaryLocationLineHash                                               ff892574fa9e85eb:1
# primaryLocationStartColumnFingerprint                                                 70
# rule_id                                com.lgtm/javascript-queries:js/unused-local-va...
# rule_index                                                                             0
#
#                                                                                     8     \
# results_array_id                                                              4793680256
# results_array_index                                                                    8
# ruleId                                 com.lgtm/javascript-queries:js/unused-local-va...
# ruleIndex                                                                              0
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                    51
# location_endLine                                                                     292
# location_startColumn                                                                  50
# location_startLine                                                                   292
# location_index                                                                         4
# location_uri                           static/js/tinymce/jscripts/tiny_mce/plugins/ad...
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                    -1
# relatedLocation_endColumn                                                             -1
# relatedLocation_endLine                                                               -1
# relatedLocation_startColumn                                                            1
# relatedLocation_startLine                                                             -1
# relatedLocation_index                                                                 -1
# relatedLocation_uri                                                scli-dyys dummy value
# relatedLocation_uriBaseId                                          scli-dyys dummy value
# relatedLocation_message                                            scli-dyys dummy value
# message_text                                                          Unused variable v.
# primaryLocationLineHash                                               2f7867eeb9bf356b:1
# primaryLocationStartColumnFingerprint                                                 47
# rule_id                                com.lgtm/javascript-queries:js/unused-local-va...
# rule_index                                                                             0
#
#                                                                                     9     \
# results_array_id                                                              4793680256
# results_array_index                                                                    9
# ruleId                                 com.lgtm/javascript-queries:js/unused-local-va...
# ruleIndex                                                                              0
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                    55
# location_endLine                                                                     292
# location_startColumn                                                                  53
# location_startLine                                                                   292
# location_index                                                                         4
# location_uri                           static/js/tinymce/jscripts/tiny_mce/plugins/ad...
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                    -1
# relatedLocation_endColumn                                                             -1
# relatedLocation_endLine                                                               -1
# relatedLocation_startColumn                                                            1
# relatedLocation_startLine                                                             -1
# relatedLocation_index                                                                 -1
# relatedLocation_uri                                                scli-dyys dummy value
# relatedLocation_uriBaseId                                          scli-dyys dummy value
# relatedLocation_message                                            scli-dyys dummy value
# message_text                                                         Unused variable cl.
# primaryLocationLineHash                                               2f7867eeb9bf356b:1
# primaryLocationStartColumnFingerprint                                                 50
# rule_id                                com.lgtm/javascript-queries:js/unused-local-va...
# rule_index                                                                             0
#
#                                        ...  \
# results_array_id                       ...
# results_array_index                    ...
# ruleId                                 ...
# ruleIndex                              ...
# location_array_index                   ...
# location_id                            ...
# location_endColumn                     ...
# location_endLine                       ...
# location_startColumn                   ...
# location_startLine                     ...
# location_index                         ...
# location_uri                           ...
# location_uriBaseId                     ...
# location_message                       ...
# relatedLocation_array_index            ...
# relatedLocation_id                     ...
# relatedLocation_endColumn              ...
# relatedLocation_endLine                ...
# relatedLocation_startColumn            ...
# relatedLocation_startLine              ...
# relatedLocation_index                  ...
# relatedLocation_uri                    ...
# relatedLocation_uriBaseId              ...
# relatedLocation_message                ...
# message_text                           ...
# primaryLocationLineHash                ...
# primaryLocationStartColumnFingerprint  ...
# rule_id                                ...
# rule_index                             ...
#
#                                                                                     1717  \
# results_array_id                                                              4799032384
# results_array_index                                                                  419
# ruleId                                 com.lgtm/javascript-queries:js/incomplete-host...
# ruleIndex                                                                             25
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                   249
# location_endLine                                                                      20
# location_startColumn                                                                 161
# location_startLine                                                                    20
# location_index                                                                        15
# location_uri                           static/js/tinymce/jscripts/tiny_mce/plugins/me...
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                     1
# relatedLocation_endColumn                                                             72
# relatedLocation_endLine                                                              114
# relatedLocation_startColumn                                                           30
# relatedLocation_startLine                                                            114
# relatedLocation_index                                                                 15
# relatedLocation_uri                    static/js/tinymce/jscripts/tiny_mce/plugins/me...
# relatedLocation_uriBaseId                                                      %SRCROOT%
# relatedLocation_message                                                             here
# message_text                           This string, which is used as a regular expres...
# primaryLocationLineHash                                               3fece0909814abf2:1
# primaryLocationStartColumnFingerprint                                                158
# rule_id                                com.lgtm/javascript-queries:js/incomplete-host...
# rule_index                                                                            25
#
#                                                                                     1718  \
# results_array_id                                                              4799032384
# results_array_index                                                                  420
# ruleId                                 com.lgtm/javascript-queries:js/incomplete-host...
# ruleIndex                                                                             25
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                   136
# location_endLine                                                                      21
# location_startColumn                                                                  77
# location_startLine                                                                    21
# location_index                                                                        15
# location_uri                           static/js/tinymce/jscripts/tiny_mce/plugins/me...
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                     1
# relatedLocation_endColumn                                                             72
# relatedLocation_endLine                                                              114
# relatedLocation_startColumn                                                           30
# relatedLocation_startLine                                                            114
# relatedLocation_index                                                                 15
# relatedLocation_uri                    static/js/tinymce/jscripts/tiny_mce/plugins/me...
# relatedLocation_uriBaseId                                                      %SRCROOT%
# relatedLocation_message                                                             here
# message_text                           This string, which is used as a regular expres...
# primaryLocationLineHash                                               baa83464899c850f:1
# primaryLocationStartColumnFingerprint                                                 74
# rule_id                                com.lgtm/javascript-queries:js/incomplete-host...
# rule_index                                                                            25
#
#                                                                                     1719  \
# results_array_id                                                              4799032384
# results_array_index                                                                  421
# ruleId                                 com.lgtm/javascript-queries:js/incomplete-host...
# ruleIndex                                                                             25
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                   173
# location_endLine                                                                      22
# location_startColumn                                                                  89
# location_startLine                                                                    22
# location_index                                                                        15
# location_uri                           static/js/tinymce/jscripts/tiny_mce/plugins/me...
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                     1
# relatedLocation_endColumn                                                             72
# relatedLocation_endLine                                                              114
# relatedLocation_startColumn                                                           30
# relatedLocation_startLine                                                            114
# relatedLocation_index                                                                 15
# relatedLocation_uri                    static/js/tinymce/jscripts/tiny_mce/plugins/me...
# relatedLocation_uriBaseId                                                      %SRCROOT%
# relatedLocation_message                                                             here
# message_text                           This string, which is used as a regular expres...
# primaryLocationLineHash                                               8ad5248e23031514:1
# primaryLocationStartColumnFingerprint                                                 86
# rule_id                                com.lgtm/javascript-queries:js/incomplete-host...
# rule_index                                                                            25
#
#                                                                                     1720  \
# results_array_id                                                              4799032384
# results_array_index                                                                  422
# ruleId                                 com.lgtm/javascript-queries:js/incomplete-host...
# ruleIndex                                                                             25
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                   172
# location_endLine                                                                      23
# location_startColumn                                                                  82
# location_startLine                                                                    23
# location_index                                                                        15
# location_uri                           static/js/tinymce/jscripts/tiny_mce/plugins/me...
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                     1
# relatedLocation_endColumn                                                             72
# relatedLocation_endLine                                                              114
# relatedLocation_startColumn                                                           30
# relatedLocation_startLine                                                            114
# relatedLocation_index                                                                 15
# relatedLocation_uri                    static/js/tinymce/jscripts/tiny_mce/plugins/me...
# relatedLocation_uriBaseId                                                      %SRCROOT%
# relatedLocation_message                                                             here
# message_text                           This string, which is used as a regular expres...
# primaryLocationLineHash                                               fa7eb8938ebc8874:1
# primaryLocationStartColumnFingerprint                                                 79
# rule_id                                com.lgtm/javascript-queries:js/incomplete-host...
# rule_index                                                                            25
#
#                                                                                     1721  \
# results_array_id                                                              4799032384
# results_array_index                                                                  423
# ruleId                                 com.lgtm/javascript-queries:js/loop-iteration-...
# ruleIndex                                                                             26
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                    22
# location_endLine                                                                      71
# location_startColumn                                                                   5
# location_startLine                                                                    71
# location_index                                                                        70
# location_uri                           static/js/jquery-ui-1.10.3/ui/jquery.ui.droppa...
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                    -1
# relatedLocation_endColumn                                                             -1
# relatedLocation_endLine                                                               -1
# relatedLocation_startColumn                                                            1
# relatedLocation_startLine                                                             -1
# relatedLocation_index                                                                 -1
# relatedLocation_uri                                                scli-dyys dummy value
# relatedLocation_uriBaseId                                          scli-dyys dummy value
# relatedLocation_message                                            scli-dyys dummy value
# message_text                           Removing an array item without adjusting the l...
# primaryLocationLineHash                                               a0244b916b792ba9:1
# primaryLocationStartColumnFingerprint                                                  0
# rule_id                                com.lgtm/javascript-queries:js/loop-iteration-...
# rule_index                                                                            26
#
#                                                                                     1722  \
# results_array_id                                                              4799032384
# results_array_index                                                                  424
# ruleId                                 com.lgtm/javascript-queries:js/useless-regexp-...
# ruleIndex                                                                             27
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                    57
# location_endLine                                                                     220
# location_startColumn                                                                  55
# location_startLine                                                                   220
# location_index                                                                         5
# location_uri                           static/js/tinymce/jscripts/tiny_mce/plugins/ad...
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                     1
# relatedLocation_endColumn                                                             70
# relatedLocation_endLine                                                              220
# relatedLocation_startColumn                                                           39
# relatedLocation_startLine                                                            220
# relatedLocation_index                                                                  5
# relatedLocation_uri                    static/js/tinymce/jscripts/tiny_mce/plugins/ad...
# relatedLocation_uriBaseId                                                      %SRCROOT%
# relatedLocation_message                                               regular expression
# message_text                           The escape sequence '\.' is equivalent to just...
# primaryLocationLineHash                                               5bc93733f296b513:1
# primaryLocationStartColumnFingerprint                                                 53
# rule_id                                com.lgtm/javascript-queries:js/useless-regexp-...
# rule_index                                                                            27
#
#                                                                                     1723  \
# results_array_id                                                              4799032384
# results_array_index                                                                  425
# ruleId                                 com.lgtm/javascript-queries:js/useless-regexp-...
# ruleIndex                                                                             27
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                    70
# location_endLine                                                                     226
# location_startColumn                                                                  68
# location_startLine                                                                   226
# location_index                                                                         5
# location_uri                           static/js/tinymce/jscripts/tiny_mce/plugins/ad...
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                     1
# relatedLocation_endColumn                                                             78
# relatedLocation_endLine                                                              226
# relatedLocation_startColumn                                                           49
# relatedLocation_startLine                                                            226
# relatedLocation_index                                                                  5
# relatedLocation_uri                    static/js/tinymce/jscripts/tiny_mce/plugins/ad...
# relatedLocation_uriBaseId                                                      %SRCROOT%
# relatedLocation_message                                               regular expression
# message_text                           The escape sequence '\.' is equivalent to just...
# primaryLocationLineHash                                               9ce0746afae7a611:1
# primaryLocationStartColumnFingerprint                                                 65
# rule_id                                com.lgtm/javascript-queries:js/useless-regexp-...
# rule_index                                                                            27
#
#                                                                                     1724  \
# results_array_id                                                              4799032384
# results_array_index                                                                  426
# ruleId                                 com.lgtm/javascript-queries:js/useless-regexp-...
# ruleIndex                                                                             27
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                    33
# location_endLine                                                                     227
# location_startColumn                                                                  31
# location_startLine                                                                   227
# location_index                                                                         5
# location_uri                           static/js/tinymce/jscripts/tiny_mce/plugins/ad...
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                     1
# relatedLocation_endColumn                                                             54
# relatedLocation_endLine                                                              253
# relatedLocation_startColumn                                                           48
# relatedLocation_startLine                                                            253
# relatedLocation_index                                                                  5
# relatedLocation_uri                    static/js/tinymce/jscripts/tiny_mce/plugins/ad...
# relatedLocation_uriBaseId                                                      %SRCROOT%
# relatedLocation_message                                               regular expression
# message_text                           The escape sequence '\.' is equivalent to just...
# primaryLocationLineHash                                               76a7d7cbd7b16471:1
# primaryLocationStartColumnFingerprint                                                 28
# rule_id                                com.lgtm/javascript-queries:js/useless-regexp-...
# rule_index                                                                            27
#
#                                                                                     1725  \
# results_array_id                                                              4799032384
# results_array_index                                                                  427
# ruleId                                 com.lgtm/javascript-queries:js/useless-regexp-...
# ruleIndex                                                                             27
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                    97
# location_endLine                                                                      27
# location_startColumn                                                                  95
# location_startLine                                                                    27
# location_index                                                                        36
# location_uri                           static/js/tinymce/jscripts/tiny_mce/utils/vali...
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                     1
# relatedLocation_endColumn                                                             33
# relatedLocation_endLine                                                               70
# relatedLocation_startColumn                                                           32
# relatedLocation_startLine                                                             70
# relatedLocation_index                                                                 36
# relatedLocation_uri                    static/js/tinymce/jscripts/tiny_mce/utils/vali...
# relatedLocation_uriBaseId                                                      %SRCROOT%
# relatedLocation_message                                               regular expression
# message_text                           The escape sequence '\.' is equivalent to just...
# primaryLocationLineHash                                               2ed8420357e0fd27:1
# primaryLocationStartColumnFingerprint                                                 92
# rule_id                                com.lgtm/javascript-queries:js/useless-regexp-...
# rule_index                                                                            27
#
#                                                                                     1726
# results_array_id                                                              4799032384
# results_array_index                                                                  438
# ruleId                                 com.lgtm/javascript-queries:js/incomplete-mult...
# ruleIndex                                                                             30
# location_array_index                                                                   0
# location_id                                                                           -1
# location_endColumn                                                                    39
# location_endLine                                                                    2664
# location_startColumn                                                                  11
# location_startLine                                                                  2664
# location_index                                                                        39
# location_uri                                                 static/js/12o_super_mini.js
# location_uriBaseId                                                             %SRCROOT%
# location_message                                                   scli-dyys dummy value
# relatedLocation_array_index                                                            0
# relatedLocation_id                                                                     1
# relatedLocation_endColumn                                                             23
# relatedLocation_endLine                                                             2664
# relatedLocation_startColumn                                                           22
# relatedLocation_startLine                                                           2664
# relatedLocation_index                                                                 39
# relatedLocation_uri                                          static/js/12o_super_mini.js
# relatedLocation_uriBaseId                                                      %SRCROOT%
# relatedLocation_message                                                          <script
# message_text                           This string may still contain [<script](1), wh...
# primaryLocationLineHash                                               971273afe8dc89f4:1
# primaryLocationStartColumnFingerprint                                                  4
# rule_id                                com.lgtm/javascript-queries:js/incomplete-mult...
# rule_index                                                                            30
#
# [29 rows x 1727 columns]

# %%
d1["relatedLocations.csv"].T
# Out:
#                                                            0    \
# struct_id                                           4794388736
# uri          static/js/tinymce/jscripts/tiny_mce/plugins/pa...
# startLine                                                  722
# startColumn                                                 75
# endLine                                                    722
# endColumn                                                   76
# message                                                   here
#
#                                                            1    \
# struct_id                                           4794389760
# uri          static/js/tinymce/jscripts/tiny_mce/plugins/pa...
# startLine                                                  722
# startColumn                                                 74
# endLine                                                    722
# endColumn                                                   75
# message                                                   here
#
#                                                            2    \
# struct_id                                           4794389760
# uri          static/js/tinymce/jscripts/tiny_mce/plugins/pa...
# startLine                                                  722
# startColumn                                                 76
# endLine                                                    722
# endColumn                                                   77
# message                                                   here
#
#                                                            3    \
# struct_id                                           4794389760
# uri          static/js/tinymce/jscripts/tiny_mce/plugins/pa...
# startLine                                                  722
# startColumn                                                 78
# endLine                                                    722
# endColumn                                                   79
# message                                                   here
#
#                                                            4    \
# struct_id                                           4794391296
# uri          static/js/tinymce/jscripts/tiny_mce/plugins/wo...
# startLine                                                   21
# startColumn                                                 82
# endLine                                                     21
# endColumn                                                   83
# message                                                   here
#
#                                                            5    \
# struct_id                                           4794392448
# uri          static/js/tinymce/jscripts/tiny_mce/plugins/wo...
# startLine                                                   21
# startColumn                                                 85
# endLine                                                     21
# endColumn                                                   86
# message                                                   here
#
#                                                            6    \
# struct_id                                           4794405824
# uri          static/js/tinymce/jscripts/tiny_mce/plugins/wo...
# startLine                                                   22
# startColumn                                                 68
# endLine                                                     22
# endColumn                                                   69
# message                                                   here
#
#                                                            7    \
# struct_id                                           4794406848
# uri          static/js/tinymce/jscripts/tiny_mce/plugins/ta...
# startLine                                                 1027
# startColumn                                                  6
# endLine                                                   1027
# endColumn                                                   54
# message                                         this statement
#
#                                                            8    \
# struct_id                                           4794946816
# uri          static/js/tinymce/jscripts/tiny_mce/tiny_mce_s...
# startLine                                                 6758
# startColumn                                                  5
# endLine                                                   6758
# endColumn                                                    7
# message                                      this if statement
#
#                                                            9    ...  \
# struct_id                                           4794946816  ...
# uri          static/js/tinymce/jscripts/tiny_mce/tiny_mce_s...  ...
# startLine                                                 6741  ...
# startColumn                                                  4  ...
# endLine                                                   6741  ...
# endColumn                                                    6  ...
# message                                this other if statement  ...
#
#                                                            378  \
# struct_id                                           4800853824
# uri          static/js/jquery-ui-1.10.3/demos/dialog/modal-...
# startLine                                                   91
# startColumn                                                 17
# endLine                                                     91
# endColumn                                                   28
# message                                               DOM text
#
#                                                            379  \
# struct_id                                           4800853824
# uri          static/js/jquery-ui-1.10.3/demos/dialog/modal-...
# startLine                                                   92
# startColumn                                                 17
# endLine                                                     92
# endColumn                                                   31
# message                                               DOM text
#
#                                                            380  \
# struct_id                                           4800866688
# uri          static/js/jquery-ui-1.10.3/demos/droppable/pho...
# startLine                                                  103
# startColumn                                                 13
# endLine                                                    103
# endColumn                                                   50
# message                                               DOM text
#
#                                                            381  \
# struct_id                                           4800878016
# uri          static/js/jquery-ui-1.10.3/demos/tabs/manipula...
# startLine                                                   59
# startColumn                                                 16
# endLine                                                     59
# endColumn                                                   30
# message                                               DOM text
#
#                                                            382  \
# struct_id                                           4800897792
# uri          static/js/jquery-ui-1.10.3/demos/tabs/manipula...
# startLine                                                   62
# startColumn                                                 22
# endLine                                                     62
# endColumn                                                   38
# message                                               DOM text
#
#                                                            383  \
# struct_id                                           4800910272
# uri          static/js/jquery-ui-1.10.3/ui/jquery.ui.datepi...
# startLine                                                  196
# startColumn                                                 65
# endLine                                                    196
# endColumn                                                   75
# message                                      HTML construction
#
#                                                     384  \
# struct_id                                    4800910272
# uri          static/js/jquery-ui-1.10.3/ui/jquery-ui.js
# startLine                                          9598
# startColumn                                          28
# endLine                                            9598
# endColumn                                            35
# message                                   library input
#
#                                                            385  \
# struct_id                                           4800910272
# uri          static/js/jquery-ui-1.10.3/ui/jquery.ui.datepi...
# startLine                                                  196
# startColumn                                                 20
# endLine                                                    196
# endColumn                                                   87
# message                                   cross-site scripting
#
#                                                            386  \
# struct_id                                           4800910272
# uri          static/js/jquery-ui-1.10.3/ui/jquery.ui.datepi...
# startLine                                                 1998
# startColumn                                                 28
# endLine                                                   1998
# endColumn                                                   35
# message                                          library input
#
#                                        387
# struct_id                       4800910272
# uri          static/js/jquery-ui-custom.js
# startLine                              541
# startColumn                             10
# endLine                                541
# endColumn                               11
# message                      library input
#
# [7 rows x 388 columns]

# %%
d1["rules.csv"].T
# Out:
#                                                                  0    \
# rules_array_id                                            4796114688
# rules_array_index                                                  0
# id                 com.lgtm/javascript-queries:js/unused-local-va...
# name               com.lgtm/javascript-queries:js/unused-local-va...
# enabled                                                         True
# level                                                           note
# fullDescription    Unused variables, imports, functions or classe...
# shortDescription          Unused variable, import, function or class
# kind                                                         problem
# precision                                                  very-high
# security-severity                              scli-dyys dummy value
# severity                                              recommendation
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          0
# tag_text                                             maintainability
#
#                                                                  1    \
# rules_array_id                                            4796114688
# rules_array_index                                                  1
# id                 com.lgtm/javascript-queries:js/property-access...
# name               com.lgtm/javascript-queries:js/property-access...
# enabled                                                         True
# level                                                          error
# fullDescription    Trying to access a property of "null" or "unde...
# shortDescription                Property access on null or undefined
# kind                                                         problem
# precision                                                       high
# security-severity                              scli-dyys dummy value
# severity                                                       error
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          0
# tag_text                                                 correctness
#
#                                                                  2    \
# rules_array_id                                            4796114688
# rules_array_index                                                  1
# id                 com.lgtm/javascript-queries:js/property-access...
# name               com.lgtm/javascript-queries:js/property-access...
# enabled                                                         True
# level                                                          error
# fullDescription    Trying to access a property of "null" or "unde...
# shortDescription                Property access on null or undefined
# kind                                                         problem
# precision                                                       high
# security-severity                              scli-dyys dummy value
# severity                                                       error
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          1
# tag_text                                        external/cwe/cwe-476
#
#                                                                  3    \
# rules_array_id                                            4796114688
# rules_array_index                                                  2
# id                 com.lgtm/javascript-queries:js/regex/duplicate...
# name               com.lgtm/javascript-queries:js/regex/duplicate...
# enabled                                                         True
# level                                                        warning
# fullDescription    If a character class in a regular expression c...
# shortDescription              Duplicate character in character class
# kind                                                         problem
# precision                                                  very-high
# security-severity                              scli-dyys dummy value
# severity                                                     warning
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          0
# tag_text                                                 reliability
#
#                                                                  4    \
# rules_array_id                                            4796114688
# rules_array_index                                                  2
# id                 com.lgtm/javascript-queries:js/regex/duplicate...
# name               com.lgtm/javascript-queries:js/regex/duplicate...
# enabled                                                         True
# level                                                        warning
# fullDescription    If a character class in a regular expression c...
# shortDescription              Duplicate character in character class
# kind                                                         problem
# precision                                                  very-high
# security-severity                              scli-dyys dummy value
# severity                                                     warning
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          1
# tag_text                                                 correctness
#
#                                                                  5    \
# rules_array_id                                            4796114688
# rules_array_index                                                  2
# id                 com.lgtm/javascript-queries:js/regex/duplicate...
# name               com.lgtm/javascript-queries:js/regex/duplicate...
# enabled                                                         True
# level                                                        warning
# fullDescription    If a character class in a regular expression c...
# shortDescription              Duplicate character in character class
# kind                                                         problem
# precision                                                  very-high
# security-severity                              scli-dyys dummy value
# severity                                                     warning
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          2
# tag_text                                         regular-expressions
#
#                                                                  6    \
# rules_array_id                                            4796114688
# rules_array_index                                                  3
# id                 com.lgtm/javascript-queries:js/misleading-inde...
# name               com.lgtm/javascript-queries:js/misleading-inde...
# enabled                                                         True
# level                                                        warning
# fullDescription    The body of a control statement should have ap...
# shortDescription      Misleading indentation after control statement
# kind                                                         problem
# precision                                                  very-high
# security-severity                              scli-dyys dummy value
# severity                                                     warning
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          0
# tag_text                                                 correctness
#
#                                                                  7    \
# rules_array_id                                            4796114688
# rules_array_index                                                  3
# id                 com.lgtm/javascript-queries:js/misleading-inde...
# name               com.lgtm/javascript-queries:js/misleading-inde...
# enabled                                                         True
# level                                                        warning
# fullDescription    The body of a control statement should have ap...
# shortDescription      Misleading indentation after control statement
# kind                                                         problem
# precision                                                  very-high
# security-severity                              scli-dyys dummy value
# severity                                                     warning
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          1
# tag_text                                                 statistical
#
#                                                                  8    \
# rules_array_id                                            4796114688
# rules_array_index                                                  3
# id                 com.lgtm/javascript-queries:js/misleading-inde...
# name               com.lgtm/javascript-queries:js/misleading-inde...
# enabled                                                         True
# level                                                        warning
# fullDescription    The body of a control statement should have ap...
# shortDescription      Misleading indentation after control statement
# kind                                                         problem
# precision                                                  very-high
# security-severity                              scli-dyys dummy value
# severity                                                     warning
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          2
# tag_text                                            non-attributable
#
#                                                                  9    ...  \
# rules_array_id                                            4796114688  ...
# rules_array_index                                                  3  ...
# id                 com.lgtm/javascript-queries:js/misleading-inde...  ...
# name               com.lgtm/javascript-queries:js/misleading-inde...  ...
# enabled                                                         True  ...
# level                                                        warning  ...
# fullDescription    The body of a control statement should have ap...  ...
# shortDescription      Misleading indentation after control statement  ...
# kind                                                         problem  ...
# precision                                                  very-high  ...
# security-severity                              scli-dyys dummy value  ...
# severity                                                     warning  ...
# sub-severity                                   scli-dyys dummy value  ...
# tag_index                                                          3  ...
# tag_text                                        external/cwe/cwe-483  ...
#
#                                                                  259  \
# rules_array_id                                            4800968384
# rules_array_index                                                 29
# id                    com.lgtm/javascript-queries:js/xss-through-dom
# name                  com.lgtm/javascript-queries:js/xss-through-dom
# enabled                                                         True
# level                                                        warning
# fullDescription    Reinterpreting text from the DOM as HTML can l...
# shortDescription                      DOM text reinterpreted as HTML
# kind                                                    path-problem
# precision                                                       high
# security-severity                                                6.1
# severity                                                     warning
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          1
# tag_text                                        external/cwe/cwe-079
#
#                                                                  260  \
# rules_array_id                                            4800968384
# rules_array_index                                                 29
# id                    com.lgtm/javascript-queries:js/xss-through-dom
# name                  com.lgtm/javascript-queries:js/xss-through-dom
# enabled                                                         True
# level                                                        warning
# fullDescription    Reinterpreting text from the DOM as HTML can l...
# shortDescription                      DOM text reinterpreted as HTML
# kind                                                    path-problem
# precision                                                       high
# security-severity                                                6.1
# severity                                                     warning
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          2
# tag_text                                        external/cwe/cwe-116
#
#                                                                  261  \
# rules_array_id                                            4800968384
# rules_array_index                                                 30
# id                 com.lgtm/javascript-queries:js/incomplete-mult...
# name               com.lgtm/javascript-queries:js/incomplete-mult...
# enabled                                                         True
# level                                                        warning
# fullDescription    A sanitizer that removes a sequence of charact...
# shortDescription             Incomplete multi-character sanitization
# kind                                                         problem
# precision                                                       high
# security-severity                                                7.8
# severity                                                     warning
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          0
# tag_text                                                 correctness
#
#                                                                  262  \
# rules_array_id                                            4800968384
# rules_array_index                                                 30
# id                 com.lgtm/javascript-queries:js/incomplete-mult...
# name               com.lgtm/javascript-queries:js/incomplete-mult...
# enabled                                                         True
# level                                                        warning
# fullDescription    A sanitizer that removes a sequence of charact...
# shortDescription             Incomplete multi-character sanitization
# kind                                                         problem
# precision                                                       high
# security-severity                                                7.8
# severity                                                     warning
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          1
# tag_text                                                    security
#
#                                                                  263  \
# rules_array_id                                            4800968384
# rules_array_index                                                 30
# id                 com.lgtm/javascript-queries:js/incomplete-mult...
# name               com.lgtm/javascript-queries:js/incomplete-mult...
# enabled                                                         True
# level                                                        warning
# fullDescription    A sanitizer that removes a sequence of charact...
# shortDescription             Incomplete multi-character sanitization
# kind                                                         problem
# precision                                                       high
# security-severity                                                7.8
# severity                                                     warning
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          2
# tag_text                                        external/cwe/cwe-020
#
#                                                                  264  \
# rules_array_id                                            4800968384
# rules_array_index                                                 30
# id                 com.lgtm/javascript-queries:js/incomplete-mult...
# name               com.lgtm/javascript-queries:js/incomplete-mult...
# enabled                                                         True
# level                                                        warning
# fullDescription    A sanitizer that removes a sequence of charact...
# shortDescription             Incomplete multi-character sanitization
# kind                                                         problem
# precision                                                       high
# security-severity                                                7.8
# severity                                                     warning
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          3
# tag_text                                        external/cwe/cwe-080
#
#                                                                  265  \
# rules_array_id                                            4800968384
# rules_array_index                                                 30
# id                 com.lgtm/javascript-queries:js/incomplete-mult...
# name               com.lgtm/javascript-queries:js/incomplete-mult...
# enabled                                                         True
# level                                                        warning
# fullDescription    A sanitizer that removes a sequence of charact...
# shortDescription             Incomplete multi-character sanitization
# kind                                                         problem
# precision                                                       high
# security-severity                                                7.8
# severity                                                     warning
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          4
# tag_text                                        external/cwe/cwe-116
#
#                                                                  266  \
# rules_array_id                                            4800968384
# rules_array_index                                                 31
# id                 com.lgtm/javascript-queries:js/html-constructe...
# name               com.lgtm/javascript-queries:js/html-constructe...
# enabled                                                         True
# level                                                          error
# fullDescription    Using externally controlled strings to constru...
# shortDescription          Unsafe HTML constructed from library input
# kind                                                    path-problem
# precision                                                       high
# security-severity                                                6.1
# severity                                                       error
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          0
# tag_text                                                    security
#
#                                                                  267  \
# rules_array_id                                            4800968384
# rules_array_index                                                 31
# id                 com.lgtm/javascript-queries:js/html-constructe...
# name               com.lgtm/javascript-queries:js/html-constructe...
# enabled                                                         True
# level                                                          error
# fullDescription    Using externally controlled strings to constru...
# shortDescription          Unsafe HTML constructed from library input
# kind                                                    path-problem
# precision                                                       high
# security-severity                                                6.1
# severity                                                       error
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          1
# tag_text                                        external/cwe/cwe-079
#
#                                                                  268
# rules_array_id                                            4800968384
# rules_array_index                                                 31
# id                 com.lgtm/javascript-queries:js/html-constructe...
# name               com.lgtm/javascript-queries:js/html-constructe...
# enabled                                                         True
# level                                                          error
# fullDescription    Using externally controlled strings to constru...
# shortDescription          Unsafe HTML constructed from library input
# kind                                                    path-problem
# precision                                                       high
# security-severity                                                6.1
# severity                                                       error
# sub-severity                                   scli-dyys dummy value
# tag_index                                                          2
# tag_text                                        external/cwe/cwe-116
#
# [15 rows x 269 columns]
