# %% [markdown]
# ## Navigate and produce .csv tables

# %%
cd ~/local/sarif-cli/data/treeio
# Out:
# /Users/hohn/local/sarif-cli/data/treeio

# %%
# %ls
# Out:
# 2021-12-09/          multi-sarif-01.json  test_set_1.sarif
# 2022-02-25/          multi-sarif-01.yaml  test_set_1.yaml
# base-tables/         test-01/             treeio/

# %%
# !sarif-extract-multi multi-sarif-01.json base-tables

# %%
cd base-tables
# Out:
# /Users/hohn/local/sarif-cli/data/treeio/base-tables

# %%
# %ls
# Out:
# artifacts.csv         kind_problem.csv      rules.csv
# codeflows.csv         project.csv
# kind_pathproblem.csv  relatedLocations.csv

# %% [markdown]
# ## Display adjustments

# %%
from IPython.display import display, HTML

# use full display width
display(HTML("<style>.container { width:95% !important; }</style>"))

# enlarge table font size
display(HTML("<style> .rendered_html table  { font-size: 12pt !important; }</style>"))

display(HTML("<style> .rendered_html th, .rendered_html td { text-align: left !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>
# <style> .rendered_html table  { font-size: 12pt !important; }</style>
# <style> .rendered_html th, .rendered_html td { text-align: left !important; }</style>

# %% [markdown]
# ## Load tables

# %%
import pandas as pd
from collections import UserDict
d1 = UserDict()

# %%
def windowed_view(df):
    return df.style.set_sticky(axis=0).set_sticky(axis=1)

# %%
from pathlib import Path
for p in Path(".").glob("*.csv"):
    d1[p.name] = pd.read_csv(p)

# %% [markdown]
# ## ... and display all column names

# %%
d1.colnames = pd.DataFrame([_df.columns for _df in d1.values()], index=d1.keys()).T
windowed_view(d1.colnames.fillna(""))
# Out:
# <style type="text/css">
# #T_c7e7f thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_c7e7f tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# #T_c7e7f thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: white;
#   top: 0px;
#   z-index: 2;
# }
# </style>
# <table id="T_c7e7f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7e7f_level0_col0" class="col_heading level0 col0" >codeflows.csv</th>
#       <th id="T_c7e7f_level0_col1" class="col_heading level0 col1" >artifacts.csv</th>
#       <th id="T_c7e7f_level0_col2" class="col_heading level0 col2" >project.csv</th>
#       <th id="T_c7e7f_level0_col3" class="col_heading level0 col3" >relatedLocations.csv</th>
#       <th id="T_c7e7f_level0_col4" class="col_heading level0 col4" >kind_pathproblem.csv</th>
#       <th id="T_c7e7f_level0_col5" class="col_heading level0 col5" >rules.csv</th>
#       <th id="T_c7e7f_level0_col6" class="col_heading level0 col6" >kind_problem.csv</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7e7f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7e7f_row0_col0" class="data row0 col0" >index</td>
#       <td id="T_c7e7f_row0_col1" class="data row0 col1" >index</td>
#       <td id="T_c7e7f_row0_col2" class="data row0 col2" >index</td>
#       <td id="T_c7e7f_row0_col3" class="data row0 col3" >index</td>
#       <td id="T_c7e7f_row0_col4" class="data row0 col4" >index</td>
#       <td id="T_c7e7f_row0_col5" class="data row0 col5" >index</td>
#       <td id="T_c7e7f_row0_col6" class="data row0 col6" >index</td>
#     </tr>
#     <tr>
#       <th id="T_c7e7f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7e7f_row1_col0" class="data row1 col0" >t9799_array_id</td>
#       <td id="T_c7e7f_row1_col1" class="data row1 col1" >array_id</td>
#       <td id="T_c7e7f_row1_col2" class="data row1 col2" >value_index_7481</td>
#       <td id="T_c7e7f_row1_col3" class="data row1 col3" >struct_id</td>
#       <td id="T_c7e7f_row1_col4" class="data row1 col4" >t6343_result_id</td>
#       <td id="T_c7e7f_row1_col5" class="data row1 col5" >t8754_array_id</td>
#       <td id="T_c7e7f_row1_col6" class="data row1 col6" >result_id_6343</td>
#     </tr>
#     <tr>
#       <th id="T_c7e7f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c7e7f_row2_col0" class="data row2 col0" >t9799_idx</td>
#       <td id="T_c7e7f_row2_col1" class="data row2 col1" >artifact_index_4640</td>
#       <td id="T_c7e7f_row2_col2" class="data row2 col2" >creation_date</td>
#       <td id="T_c7e7f_row2_col3" class="data row2 col3" >uri</td>
#       <td id="T_c7e7f_row2_col4" class="data row2 col4" >t6343_result_idx</td>
#       <td id="T_c7e7f_row2_col5" class="data row2 col5" >t8754_value_index</td>
#       <td id="T_c7e7f_row2_col6" class="data row2 col6" >results_idx_6343</td>
#     </tr>
#     <tr>
#       <th id="T_c7e7f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c7e7f_row3_col0" class="data row3 col0" >t1597_idx</td>
#       <td id="T_c7e7f_row3_col1" class="data row3 col1" >location_index_2685</td>
#       <td id="T_c7e7f_row3_col2" class="data row3 col2" >primary_language</td>
#       <td id="T_c7e7f_row3_col3" class="data row3 col3" >startLine</td>
#       <td id="T_c7e7f_row3_col4" class="data row3 col4" >t9699_codeFlows</td>
#       <td id="T_c7e7f_row3_col5" class="data row3 col5" >t6818_id</td>
#       <td id="T_c7e7f_row3_col6" class="data row3 col6" >relatedLocations_id</td>
#     </tr>
#     <tr>
#       <th id="T_c7e7f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c7e7f_row4_col0" class="data row4 col0" >t1075_locations_idx</td>
#       <td id="T_c7e7f_row4_col1" class="data row4 col1" >location_uri_2685</td>
#       <td id="T_c7e7f_row4_col2" class="data row4 col2" >project_name</td>
#       <td id="T_c7e7f_row4_col3" class="data row4 col3" >startColumn</td>
#       <td id="T_c7e7f_row4_col4" class="data row4 col4" >t9699_relatedLocations</td>
#       <td id="T_c7e7f_row4_col5" class="data row4 col5" >t6818_name</td>
#       <td id="T_c7e7f_row4_col6" class="data row4 col6" >ruleId</td>
#     </tr>
#     <tr>
#       <th id="T_c7e7f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c7e7f_row5_col0" class="data row5 col0" >id_2683</td>
#       <td id="T_c7e7f_row5_col1" class="data row5 col1" >location_uriBaseId_2685</td>
#       <td id="T_c7e7f_row5_col2" class="data row5 col2" >query_commit_id</td>
#       <td id="T_c7e7f_row5_col3" class="data row5 col3" >endLine</td>
#       <td id="T_c7e7f_row5_col4" class="data row5 col4" >t9699_ruleId</td>
#       <td id="T_c7e7f_row5_col5" class="data row5 col5" >t8581_enabled</td>
#       <td id="T_c7e7f_row5_col6" class="data row5 col6" >ruleIndex</td>
#     </tr>
#     <tr>
#       <th id="T_c7e7f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c7e7f_row6_col0" class="data row6 col0" >endColumn</td>
#       <td id="T_c7e7f_row6_col1" class="data row6 col1" ></td>
#       <td id="T_c7e7f_row6_col2" class="data row6 col2" >sarif_file_name</td>
#       <td id="T_c7e7f_row6_col3" class="data row6 col3" >endColumn</td>
#       <td id="T_c7e7f_row6_col4" class="data row6 col4" >t9699_ruleIndex</td>
#       <td id="T_c7e7f_row6_col5" class="data row6 col5" >t8581_level</td>
#       <td id="T_c7e7f_row6_col6" class="data row6 col6" >value_index</td>
#     </tr>
#     <tr>
#       <th id="T_c7e7f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c7e7f_row7_col0" class="data row7 col0" >endLine</td>
#       <td id="T_c7e7f_row7_col1" class="data row7 col1" ></td>
#       <td id="T_c7e7f_row7_col2" class="data row7 col2" >scan_id</td>
#       <td id="T_c7e7f_row7_col3" class="data row7 col3" >message</td>
#       <td id="T_c7e7f_row7_col4" class="data row7 col4" >t0350_location_idx</td>
#       <td id="T_c7e7f_row7_col5" class="data row7 col5" >t6818_t2774_fullDescription</td>
#       <td id="T_c7e7f_row7_col6" class="data row7 col6" >id_2683</td>
#     </tr>
#     <tr>
#       <th id="T_c7e7f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c7e7f_row8_col0" class="data row8 col0" >startColumn</td>
#       <td id="T_c7e7f_row8_col1" class="data row8 col1" ></td>
#       <td id="T_c7e7f_row8_col2" class="data row8 col2" >scan_start_date</td>
#       <td id="T_c7e7f_row8_col3" class="data row8 col3" ></td>
#       <td id="T_c7e7f_row8_col4" class="data row8 col4" >id_2683</td>
#       <td id="T_c7e7f_row8_col5" class="data row8 col5" >t6818_t2774_shortDescription</td>
#       <td id="T_c7e7f_row8_col6" class="data row8 col6" >endColumn</td>
#     </tr>
#     <tr>
#       <th id="T_c7e7f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c7e7f_row9_col0" class="data row9 col0" >startLine</td>
#       <td id="T_c7e7f_row9_col1" class="data row9 col1" ></td>
#       <td id="T_c7e7f_row9_col2" class="data row9 col2" >scan_stop_date</td>
#       <td id="T_c7e7f_row9_col3" class="data row9 col3" ></td>
#       <td id="T_c7e7f_row9_col4" class="data row9 col4" >endColumn</td>
#       <td id="T_c7e7f_row9_col5" class="data row9 col5" >t7849_kind</td>
#       <td id="T_c7e7f_row9_col6" class="data row9 col6" >endLine</td>
#     </tr>
#     <tr>
#       <th id="T_c7e7f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c7e7f_row10_col0" class="data row10 col0" >location_index_2685</td>
#       <td id="T_c7e7f_row10_col1" class="data row10 col1" ></td>
#       <td id="T_c7e7f_row10_col2" class="data row10 col2" >tool_name</td>
#       <td id="T_c7e7f_row10_col3" class="data row10 col3" ></td>
#       <td id="T_c7e7f_row10_col4" class="data row10 col4" >endLine</td>
#       <td id="T_c7e7f_row10_col5" class="data row10 col5" >t7849_precision</td>
#       <td id="T_c7e7f_row10_col6" class="data row10 col6" >startColumn</td>
#     </tr>
#     <tr>
#       <th id="T_c7e7f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c7e7f_row11_col0" class="data row11 col0" >uri</td>
#       <td

# %% [markdown]
# ## ... and get details of some tables

# %%
windowed_view(d1["artifacts.csv"])
# Out:
# <style type="text/css">
# #T_07de3 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_07de3 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# #T_07de3 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: white;
#   top: 0px;
#   z-index: 2;
# }
# </style>
# <table id="T_07de3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07de3_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_07de3_level0_col1" class="col_heading level0 col1" >array_id</th>
#       <th id="T_07de3_level0_col2" class="col_heading level0 col2" >artifact_index_4640</th>
#       <th id="T_07de3_level0_col3" class="col_heading level0 col3" >location_index_2685</th>
#       <th id="T_07de3_level0_col4" class="col_heading level0 col4" >location_uri_2685</th>
#       <th id="T_07de3_level0_col5" class="col_heading level0 col5" >location_uriBaseId_2685</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07de3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07de3_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_07de3_row0_col1" class="data row0 col1" >4884865856</td>
#       <td id="T_07de3_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_07de3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_07de3_row0_col4" class="data row0 col4" >static/js/fileuploader.js</td>
#       <td id="T_07de3_row0_col5" class="data row0 col5" >%SRCROOT%</td>
#     </tr>
#     <tr>
#       <th id="T_07de3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_07de3_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_07de3_row1_col1" class="data row1 col1" >4884865856</td>
#       <td id="T_07de3_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_07de3_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_07de3_row1_col4" class="data row1 col4" >static/js/hardtree.js</td>
#       <td id="T_07de3_row1_col5" class="data row1 col5" >%SRCROOT%</td>
#     </tr>
#     <tr>
#       <th id="T_07de3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_07de3_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_07de3_row2_col1" class="data row2 col1" >4884865856</td>
#       <td id="T_07de3_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_07de3_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_07de3_row2_col4" class="data row2 col4" >static/js/jquery-ui-1.10.3/demos/accordion/hoverintent.html</td>
#       <td id="T_07de3_row2_col5" class="data row2 col5" >%SRCROOT%</td>
#     </tr>
#     <tr>
#       <th id="T_07de3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_07de3_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_07de3_row3_col1" class="data row3 col1" >4884865856</td>
#       <td id="T_07de3_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_07de3_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_07de3_row3_col4" class="data row3 col4" >static/js/jquery.ganttView.js</td>
#       <td id="T_07de3_row3_col5" class="data row3 col5" >%SRCROOT%</td>
#     </tr>
#     <tr>
#       <th id="T_07de3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_07de3_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_07de3_row4_col1" class="data row4 col1" >4884865856</td>
#       <td id="T_07de3_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_07de3_row4_col3" class="data row4 col3" >4</td>
#       <td id="T_07de3_row4_col4" class="data row4 col4" >static/js/tinymce/jscripts/tiny_mce/plugins/advimage/js/image.js</td>
#       <td id="T_07de3_row4_col5" class="data row4 col5" >%SRCROOT%</td>
#     </tr>
#     <tr>
#       <th id="T_07de3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_07de3_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_07de3_row5_col1" class="data row5 col1" >4884865856</td>
#       <td id="T_07de3_row5_col2" class="data row5 col2" >5</td>
#       <td id="T_07de3_row5_col3" class="data row5 col3" >5</td>
#       <td id="T_07de3_row5_col4" class="data row5 col4" >static/js/tinymce/jscripts/tiny_mce/plugins/advlink/js/advlink.js</td>
#       <td id="T_07de3_row5_col5" class="data row5 col5" >%SRCROOT%</td>
#     </tr>
#     <tr>
#       <th id="T_07de3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_07de3_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_07de3_row6_col1" class="data row6 col1" >4884865856</td>
#       <td id="T_07de3_row6_col2" class="data row6 col2" >6</td>
#       <td id="T_07de3_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_07de3_row6_col4" class="data row6 col4" >static/js/tinymce/jscripts/tiny_mce/plugins/contextmenu/editor_plugin_src.js</td>
#       <td id="T_07de3_row6_col5" class="data row6 col5" >%SRCROOT%</td>
#     </tr>
#     <tr>
#       <th id="T_07de3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_07de3_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_07de3_row7_col1" class="data row7 col1" >4884865856</td>
#       <td id="T_07de3_row7_col2" class="data row7 col2" >7</td>
#       <td id="T_07de3_row7_col3" class="data row7 col3" >7</td>
#       <td id="T_07de3_row7_col4" class="data row7 col4" >static/js/tinymce/jscripts/tiny_mce/plugins/emotions/js/emotions.js</td>
#       <td id="T_07de3_row7_col5" class="data row7 col5" >%SRCROOT%</td>
#     </tr>
#     <tr>
#       <th id="T_07de3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_07de3_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_07de3_row8_col1" class="data row8 col1" >4884865856</td>
#       <td id="T_07de3_row8_col2" class="data row8 col2" >8</td>
#       <td id="T_07de3_row8_col3" class="data row8 col3" >8</td>
#       <td id="T_07de3_row8_col4" class="data row8 col4" >static/js/tinymce/jscripts/tiny_mce/plugins/fullpage/editor_plugin_src.js</td>
#       <td id="T_07de3_row8_col5" class="data row8 col5" >%SRCROOT%</td>
#     </tr>
#     <tr>
#       <th id="T_07de3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_07de3_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_07de3_row9_col1" class="data row9 col1" >4884865856</td>
#       <td id="T_07de3_row9_col2" class="data row9 col2" >9</td>
#       <td id="T_07de3_row9_col3" class="data row9 col3" >9</td>
#       <td id="T_07de3_row9_col4" class="data row9 col4" >static/js/tinymce/jscripts/tiny_mce/plugins/fullscreen/editor_plugin_src.js</td>
#       <td id="T_07de3_row9_col5" class="data row9 col5" >%SRCROOT%</td>
#     </tr>
#     <tr>
#       <th id="T_07de3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_07de3_row10_col0" class="data row10 col0" >10</td>
#       <td id="T_07de3_row10_col1" class="data row10 col1" >4884865856</td>
#       <td id="T_07de3_row10_col2" class="data row10 col2" >10</td>
#       <td id="T_07de3_row10_col3" class="data row10 col3" >10</td>
#       <td id="T_07de3_row10_col4" class="data row10 col4" >static/js/tinymce/jscripts/tiny_mce/plugins/fullscreen/fullscreen.htm</td>
#       <td id="T_07de3_row10_col5" class="data row10 col5" >%SRCROOT%</td>
#     </tr>
#     <tr>
#       <th id="T_07de3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_07de3_row11_col0" class="data row11 col0" >11</td>
#       <td id="T_07de3_row11_col1" class="data row11 col1" >4884865856</td>
#       <td id="T_07de3_row11_col2" class="data row11 col2" >11</td>
#       <td id="T_07de3_row11_col3" class="data row11 col3" >11</td>
#       <td id="T_07de3_row11_col4" class="data row11 col4" >static/js/tinymce/jscripts/tiny_mce/plugins/inlinepopups/editor_plugin_src.js</td>
#       <td id="T_07de3_row11_col5" class="data row11 col5" >%SRCROOT%</td>
#     </tr>
#     <tr>
#       <th id="T_07de3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_07de3_row12_col0" class="data row12 col0" >12</td>
#       <td id="T_07de3_row12_col1" class="data row12 col1" >4884865856</td>
#       <td id="T_07de3_row12_col2" class="data row12 col2" >12</td>
#       <td i

# %%
d1["project.csv"].T
# Out:
#                                                                                  0  \
# index                                                                            0
# value_index_7481                                                                 0
# creation_date                                                           2021-12-09
# primary_language                                                        javascript
# project_name                                                         treeio/treeio
# query_commit_id                                                         fa9571646c
# sarif_file_name                                           2021-12-09/results.sarif
# scan_id                                                                     123456
# scan_start_date                                                         2021-12-09
# scan_stop_date                                                          2021-12-10
# tool_name                                                                   codeql
# tool_version                                                                 v1.27
# $schema                          https://raw.githubusercontent.com/oasis-tcs/sa...
# version_6787                                                                 2.1.0
# value_index_0177                                                                 0
# artifacts                                                               4884865856
# columnKind                                                          utf16CodeUnits
# results                                                                 4884866112
# semmle.formatSpecifier                                                       2.1.0
# semmle.sourceLanguage                                                   javascript
# driver_name_7820                                                          LGTM.com
# organization                                                                Semmle
# rules                                                                   4887304640
# driver_version_7820                                                1.29.0-SNAPSHOT
# versionControl_value_index_5511                                                  0
# repositoryUri                                 https://github.com/treeio/treeio.git
# revisionId                                bae3115f4015aad2cbc5ab45572232ceec990495
#
#                                                                                  1  \
# index                                                                            1
# value_index_7481                                                                 0
# creation_date                                                           2021-12-09
# primary_language                                                        javascript
# project_name                                                         treeio/treeio
# query_commit_id                                                         fa9571646c
# sarif_file_name                                           2021-12-09/results.sarif
# scan_id                                                                     123456
# scan_start_date                                                         2021-12-09
# scan_stop_date                                                          2021-12-10
# tool_name                                                                   codeql
# tool_version                                                                 v1.27
# $schema                          https://raw.githubusercontent.com/oasis-tcs/sa...
# version_6787                                                                 2.1.0
# value_index_0177                                                                 1
# artifacts                                                               4887304320
# columnKind                                                       unicodeCodePoints
# results                                                                 4887335744
# semmle.formatSpecifier                                                       2.1.0
# semmle.sourceLanguage                                                       python
# driver_name_7820                                                          LGTM.com
# organization                                                                Semmle
# rules                                                                   4888795328
# driver_version_7820                                                1.29.0-SNAPSHOT
# versionControl_value_index_5511                                                  0
# repositoryUri                                 https://github.com/treeio/treeio.git
# revisionId                                bae3115f4015aad2cbc5ab45572232ceec990495
#
#                                                                              2  \
# index                                                                        2
# value_index_7481                                                             1
# creation_date                                                       2022-02-25
# primary_language                                                    javascript
# project_name                                                     treeio/treeio
# query_commit_id                                                     fa9571646c
# sarif_file_name                                       2022-02-25/results.sarif
# scan_id                                                                 123457
# scan_start_date                                                     2022-02-25
# scan_stop_date                                                      2022-02-26
# tool_name                                                               codeql
# tool_version                                                             v1.29
# $schema                          https://json.schemastore.org/sarif-2.1.0.json
# version_6787                                                             2.1.0
# value_index_0177                                                             0
# artifacts                                                           4888795840
# columnKind                                                   unicodeCodePoints
# results                                                             4888830016
# semmle.formatSpecifier                                                   2.1.0
# semmle.sourceLanguage                                                   python
# driver_name_7820                                                      LGTM.com
# organization                                                            Semmle
# rules                                                               4890226048
# driver_version_7820                                            1.31.0-SNAPSHOT
# versionControl_value_index_5511                                              0
# repositoryUri                             https://github.com/treeio/treeio.git
# revisionId                            bae3115f4015aad2cbc5ab45572232ceec990495
#
#                                                                              3
# index                                                                        3
# value_index_7481                                                             1
# creation_date                                                       2022-02-25
# primary_language                                                    javascript
# project_name                                                     treeio/treeio
# query_commit_id                                                     fa9571646c
# sarif_file_name                                       2022-02-25/results.sarif
# scan_id                                                                 123457
# scan_start_date                                                     2022-02-25
# scan_stop_date                                                      2022-02-26
# tool_name                                                               codeql
# tool_version                                                             v1.29
# $schema                          https://json.schemastore.org/sarif-2.1.0.json
# version_6787                                                             2.1.0
# value_index_0177                                                             1
# artifacts                                                           4890225536
# columnKind                                                      utf16CodeUnits
# results                                                             4890226432
# semmle.formatSpecifier                                                   2.1.0
# semmle.sourceLanguage                                               javascript
# driver_name_7820                                                      LGTM.com
# organization                                                            Semmle
# rules                                                               4892162432
# driver_version_7820                                            1.31.0-SNAPSHOT
# versionControl_value_index_5511                                              0
# repositoryUri                             https://github.com/treeio/treeio.git
# revisionId                            bae3115f4015aad2cbc5ab45572232ceec990495
